# %% [markdown]
# <a href="https://colab.research.google.com/github/Ebonica/COB-DATA-SCIENCE-EBONICA-SALETH-/blob/main/CODESONBYTES(DATA_SCIENCE_PHASE2_TASK2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TRAIN A SIMPLE LINEAR REGRESSING MODEL ON DATASET AND PREDICT THE
# OUTPUT**

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# **LOADING THE GIVEN DATASET**

# %%
pip install pandas gspread oauth2client scikit-learn

# %% [markdown]
# **READING THE GIVEN DATASET**

# %%
train_url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vRTK2NvcndgPX41Czu6Ft2Ho_nE-z50BgTqdzwFW0rsJ2nvyNLe2DoIg1COzUbgw80oaRBjfy5-WtFk/pubhtml'
train_df = pd.read_html(train_url, header=0)[0]

test_url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vRyvZ7lknwiSghK9aen1SaTEYoN3JS40rrGLpcyrsVZy1tB2T4gn6Y3-cdzPUFCPMmmqREWefW3kl4_/pubhtml'
test_df = pd.read_html(test_url, header=0)[0]

# %%
train_df
# Out:
#      Unnamed: 0 Unnamed: 1   Unnamed: 2
# 0             1          x            y
# 1             2         24  21.54945196
# 2             3         50  47.46446305
# 3             4         15  17.21865634
# 4             5         38  36.58639803
# ..          ...        ...          ...
# 696         697         58  58.59500642
# 697         698         93  94.62509374
# 698         699         82  88.60376995
# 699         700         66  63.64868529
# 700         701         97   94.9752655
#
# [701 rows x 3 columns]

# %% [markdown]
# **DROPING THE COLUMN IN TRAIN DATASET**

# %%
train_df.drop("Unnamed: 0", axis=1, inplace=True)
train_df.to_csv("updated_dataset.csv", index=False)

# %%
train_df
# Out:
#     Unnamed: 1   Unnamed: 2
# 0            x            y
# 1           24  21.54945196
# 2           50  47.46446305
# 3           15  17.21865634
# 4           38  36.58639803
# ..         ...          ...
# 696         58  58.59500642
# 697         93  94.62509374
# 698         82  88.60376995
# 699         66  63.64868529
# 700         97   94.9752655
#
# [701 rows x 2 columns]

# %% [markdown]
# **RENAMING COLUMNS IN TRAIN DATASET**

# %%
train_df.rename(columns={'Unnamed: 1':'x','Unnamed: 2':'y'},inplace=True)

# %%
train_df = train_df.drop(0)

# %%
train_df
# Out:
#       x            y
# 1    24  21.54945196
# 2    50  47.46446305
# 3    15  17.21865634
# 4    38  36.58639803
# 5    87  87.28898389
# ..   ..          ...
# 696  58  58.59500642
# 697  93  94.62509374
# 698  82  88.60376995
# 699  66  63.64868529
# 700  97   94.9752655
#
# [700 rows x 2 columns]

# %%
test_df
# Out:
#      Unnamed: 0 Unnamed: 1   Unnamed: 2
# 0             1          x            y
# 1             2         77  79.77515201
# 2             3         21  23.17727887
# 3             4         22  25.60926156
# 4             5         20  17.85738813
# ..          ...        ...          ...
# 296         297         71   68.5458879
# 297         298         46  47.33487629
# 298         299         55  54.09063686
# 299         300         62  63.29717058
# 300         301         47  52.45946688
#
# [301 rows x 3 columns]

# %% [markdown]
# **DROPING THE COLUMN IN TEST DATASET**

# %%
test_df.drop("Unnamed: 0", axis=1, inplace=True)
test_df.to_csv("Test.csv", index=False)

# %% [markdown]
# **RENAMING THE COLUMNS IN TEST DATASET**

# %%
test_df.rename(columns={'Unnamed: 1':'x','Unnamed: 2':'y'},inplace=True)

# %%
test_df = test_df.drop(0)

# %%
test_df
# Out:
#       x            y
# 1    77  79.77515201
# 2    21  23.17727887
# 3    22  25.60926156
# 4    20  17.85738813
# 5    36  41.84986439
# ..   ..          ...
# 296  71   68.5458879
# 297  46  47.33487629
# 298  55  54.09063686
# 299  62  63.29717058
# 300  47  52.45946688
#
# [300 rows x 2 columns]

# %% [markdown]
# **DATA ANALYSIS IN TRAIN DATASET**

# %%
print("First few rows of the dataset:")
print(train_df.head())
# Out:
# First few rows of the dataset:
#     x            y
# 1  24  21.54945196
# 2  50  47.46446305
# 3  15  17.21865634
# 4  38  36.58639803
# 5  87  87.28898389

# %%
print("Last few rows of the dataset:")
print(train_df.tail())
# Out:
# Last few rows of the dataset:
#       x            y
# 696  58  58.59500642
# 697  93  94.62509374
# 698  82  88.60376995
# 699  66  63.64868529
# 700  97   94.9752655

# %%
print("Dataset Information:")
print(train_df.info())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 1 to 700
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       700 non-null    object
#  1   y       699 non-null    object
# dtypes: object(2)
# memory usage: 11.1+ KB
# None

# %%
print("\nSummary statistics:")
print(train_df.describe())
# Out:
# Summary statistics:
#           x            y
# count   700          699
# unique  102          699
# top      58  21.54945196
# freq     16            1

# %%
print("\nMissing Values:")
print(train_df.isnull().sum())
# Out:
# Missing Values:
# x    0
# y    1
# dtype: int64

# %%
train_df = train_df.dropna(subset=['y'])

# %%
print("\nColumns:")
print(train_df.columns)
# Out:
# Columns:
# Index(['x', 'y'], dtype='object')

# %%
print("\nShape:")
print(train_df.shape)
# Out:
# Shape:
# (699, 2)

# %%
print("\nDATA TYPES:")
print(train_df.dtypes)
# Out:
# DATA TYPES:
# x    object
# y    object
# dtype: object

# %%
print("\n Access the 9th row (index 8)")
train_df.iloc[8]
# Out:
#  Access the 9th row (index 8)
# x             25
# y    24.61215147
# Name: 9, dtype: object

# %%
unique_counts = train_df.nunique()
print("Number of unique values in each column:")
print(unique_counts)
# Out:
# Number of unique values in each column:
# x    101
# y    699
# dtype: int64

# %%
nunique_counts = train_df.nunique()


for column in train_df.columns:
    unique_values = train_df[column].unique()
    value_counts = train_df[column].value_counts()

    print(f"Column: {column}")
    print(f"Number of unique values: {nunique_counts[column]}")
    print(f"Unique values: {unique_values}")
    print(f"Value counts:\n{value_counts}\n")
# Out:
# Column: x
# Number of unique values: 101
# Unique values: ['24' '50' '15' '38' '87' '36' '12' '81' '25' '5' '16' '39' '54' '60' '26'
#  '73' '29' '31' '68' '58' '84' '49' '20' '90' '48' '4' '42' '0' '93' '7'
#  '21' '19' '59' '51' '33' '85' '44' '14' '9' '75' '69' '10' '17' '74' '64'
#  '32' '41' '3' '11' '83' '76' '95' '53' '77' '55' '35' '86' '13' '46' '8'
#  '71' '28' '56' '79' '89' '27' '70' '45' '37' '47' '80' '94' '99' '65'
#  '100' '6' '2' '82' '57' '52' '97' '61' '62' '72' '78' '18' '67' '66' '98'
#  '91' '40' '96' '1' '34' '92' '88' '30' '22' '23' '63' '43']
# Value counts:
# 58    16
# 49    14
# 25    13
# 16    13
# 24    13
#       ..
# 23     3
# 63     3
# 69     2
# 82     2
# 40     2
# Name: x, Length: 101, dtype: int64
#
# Column: y
# Number of unique values: 699
# Unique values: ['21.54945196' '47.46446305' '17.21865634' '36.58639803' '87.28898389'
#  '32.46387493' '10.78089683' '80.7633986' '24.61215147' '6.963319071'
# ...

# %% [markdown]
# **DATA ANALYSIS FOR TEST DATASET**

# %%
print("First few rows of the dataset:")
print(test_df.head())
# Out:
# First few rows of the dataset:
#     x            y
# 1  77  79.77515201
# 2  21  23.17727887
# 3  22  25.60926156
# 4  20  17.85738813
# 5  36  41.84986439

# %%
print("Last few rows of the dataset:")
print(test_df.tail())
# Out:
# Last few rows of the dataset:
#       x            y
# 296  71   68.5458879
# 297  46  47.33487629
# 298  55  54.09063686
# 299  62  63.29717058
# 300  47  52.45946688

# %%
print("Dataset Information:")
print(test_df.info())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 1 to 300
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       300 non-null    object
#  1   y       300 non-null    object
# dtypes: object(2)
# memory usage: 4.8+ KB
# None

# %%
print("\nSummary statistics:")
print(test_df.describe())
# Out:
# Summary statistics:
#           x            y
# count   300          300
# unique   97          300
# top      21  79.77515201
# freq      6            1

# %%
print("\nMissing Values:")
print(test_df.isnull().sum())
# Out:
# Missing Values:
# x    0
# y    0
# dtype: int64

# %%
print("\nColumns:")
print(test_df.columns)
# Out:
# Columns:
# Index(['x', 'y'], dtype='object')

# %%
print("\nShape:")
print(test_df.shape)
# Out:
# Shape:
# (300, 2)

# %%
print("\nDATA TYPES:")
print(test_df.dtypes)
# Out:
# DATA TYPES:
# x    object
# y    object
# dtype: object

# %%
print("\n Access the 11th row (index 10)")
test_df.iloc[10]
# Out:
#  Access the 11th row (index 10)
# x              4
# y    2.811415826
# Name: 11, dtype: object

# %%
unique_counts = test_df.nunique()
print("Number of unique values in each column:")
print(unique_counts)
# Out:
# Number of unique values in each column:
# x     97
# y    300
# dtype: int64

# %%
nunique_counts = test_df.nunique()


for column in test_df.columns:
    unique_values = test_df[column].unique()
    value_counts = test_df[column].value_counts()

    print(f"Column: {column}")
    print(f"Number of unique values: {nunique_counts[column]}")
    print(f"Unique values: {unique_values}")
    print(f"Value counts:\n{value_counts}\n")
# Out:
# Column: x
# Number of unique values: 97
# Unique values: ['77' '21' '22' '20' '36' '15' '62' '95' '5' '4' '19' '96' '65' '14' '87'
#  '69' '89' '51' '27' '97' '58' '79' '93' '99' '31' '33' '80' '28' '47'
#  '53' '91' '71' '50' '76' '37' '70' '68' '40' '35' '94' '88' '52' '59' '0'
#  '39' '64' '57' '13' '72' '61' '82' '18' '41' '55' '46' '81' '84' '56'
#  '48' '100' '43' '67' '38' '63' '60' '73' '32' '2' '74' '42' '12' '1' '90'
#  '16' '66' '24' '17' '98' '78' '29' '75' '25' '30' '9' '7' '54' '49' '92'
#  '26' '23' '45' '44' '86' '6' '34' '8' '11']
# Value counts:
# 21    6
# 55    6
# 46    6
# 72    5
# 16    5
#      ..
# 9     1
# 30    1
# 29    1
# 98    1
# 11    1
# Name: x, Length: 97, dtype: int64
#
# Column: y
# Number of unique values: 300
# Unique values: ['79.77515201' '23.17727887' '25.60926156' '17.85738813' '41.84986439'
#  '9.805234876' '58.87465933' '97.61793701' '18.39512747' '8.746747654'
#  '2.811415826' '17.09537241' '95.14907176' '61.38800663' '40.24701716'
# ...

# %% [markdown]
# **BUILDING A SIMPLE LINEAR REGRESSION MODEL**

# %%
X_train = train_df[['x']]
y_train = train_df['y']


model = LinearRegression()
model.fit(X_train, y_train)


X_test = test_df[['x']]
y_pred = model.predict(X_test)


print("Predicted y values for the test dataset:")
print(y_pred)
# Out:
# Predicted y values for the test dataset:
# [76.94327594 20.90651855 21.90717494 19.90586217 35.91636428 14.90258026
#  61.93343021 94.95509081 19.90586217  4.89601644  3.89536006 18.90520579
#  95.95574719 61.93343021 35.91636428 14.90258026 64.93539936 13.90192388
#  86.94983976 68.93802488 88.95115252 50.92621001 88.95115252 26.91045685
#  96.95640358 57.93080468 78.9445887  20.90651855 92.95377805 26.91045685
#  98.95771634 30.91308237 32.91439514 79.94524508 27.91111323 46.92358448
#  52.92752277 68.93802488 27.91111323 32.91439514 90.95246528 70.93933765
#  49.92555363 75.94261956  3.89536006 36.91702066 69.93868127 67.9373685
#  39.91898981 34.9157079  93.95443443 87.95049614 51.92686639 30.91308237
#  58.93146107 -0.10726546 38.91833343 63.93474297 68.93802488 56.9301483
#  12.9012675  71.93999403 75.94261956 60.93277383 81.94655785 17.90454941
#  40.91964619 49.92555363 54.92883554 12.9012675  45.9229281  12.9012675
# ...

# %%
y_test = test_df[['y']]
mse = mean_squared_error(y_test, y_pred)

print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 9.432922192039305

# %%
r2 = r2_score(y_test, y_pred)

print("R-squared (R2):", r2)
# Out:
# R-squared (R2): 0.9888014444327563
